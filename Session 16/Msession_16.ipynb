# %% [markdown]
# # **Pandas**

# %%
import numpy as np
import pandas as pd

# %%
country = ['India','Pakistan','USA','Nepal','Srilanka']
df = pd.Series(country)

# %%
df
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
runs = [13,24,56,78,100]
runs_series = pd.Series(runs)
runs_series
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks, index = subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Hussain ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Hussain ke marks, dtype: int64

# %% [markdown]
# # Series from dictionary

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks, name = "Your Fathers marks")
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Your Fathers marks, dtype: int64

# %% [markdown]
# **Series Attributes**

# %%
# size
marks_series.size
# Out:
# 4

# %%
# d type
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Your Fathers marks'

# %%
marks_series.is_unique
# Out:
# True

# %%
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# # **Series using read_csv**

# %%
subs = pd.read_csv('/content/subs.csv')
# series = subs.iloc[:, 0]
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col ='match_no')
# series = df.iloc[:, 0]
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %% [markdown]
# # **Series methods**

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.head(3)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40

# %%
subs.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
subs.sample(5)
# Out:
#      Subscribers gained
# 74                   70
# 33                   49
# 318                 244
# 326                 259
# 355                 149

# %%
subs.value_counts()
# Out:
# Subscribers gained
# 105                   9
# 108                   6
# 88                    5
# 72                    5
# 123                   5
#                      ..
# 295                   1
# 301                   1
# 306                   1
# 312                   1
# 396                   1
# Name: count, Length: 180, dtype: int64

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.sort_values(by= 'Subscribers gained')
# Out:
#      Subscribers gained
# 42                   33
# 6                    33
# 24                   35
# 19                   37
# 14                   39
# ..                  ...
# 280                 295
# 233                 301
# 168                 306
# 331                 312
# 330                 396
#
# [365 rows x 1 columns]

# %%
subs.sort_values(by= 'Subscribers gained', ascending=False).head(1).values[0]
# Out:
# array([396])

# %%
# subs.sort_values(by= 'Subscribers gained', inplace=True)

# %% [markdown]
# # **Series Maths Methods**

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
vk.sum()
# Out:
# runs    6634
# dtype: int64

# %%
subs.prod()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
subs.median()
# Out:
# Subscribers gained    123.0
# dtype: float64

# %%
subs.mode()
# Out:
#    Subscribers gained
# 0                 105

# %%
subs.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
subs.var()
# Out:
# Subscribers gained    3928.158513
# dtype: float64

# %%
subs.min()
# Out:
# Subscribers gained    33
# dtype: int64

# %%
subs.max()
# Out:
# Subscribers gained    396
# dtype: int64

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %% [markdown]
# # **Series Indexing**

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x.iloc[-1]
# Out:
# np.int64(9)

# %%
vk[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
vk[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
vk.iloc[[1,3,6,7]]
# Out:
#           runs
# match_no
# 2           23
# 4           12
# 7           34
# 8            0

# %%
vk.iloc[[1,3,4,9]]
# Out:
#           runs
# match_no
# 2           23
# 4           12
# 5            1
# 10           3

# %% [markdown]
# # **Editing Series**

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Your Fathers marks, dtype: int64

# %%
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipython-input-3660931059.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Your Fathers marks, dtype: int64

# %%
marks_series['sst'] = 59

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         59
# Name: Your Fathers marks, dtype: int64

# %%
runs_series
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
runs_series[2:4] = [100,100]

# %%
runs_series
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
runs_series.iloc[[1,2,3]] = [0,0,0]

# %%
runs_series
# Out:
# 0     13
# 1      0
# 2      0
# 3      0
# 4    100
# dtype: int64

# %% [markdown]
# # **Series with Python Functionalities**

# %%
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
list(marks_series)
# Out:
# [67, 100, 89, 100, 59]

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(100),
#  'science': np.int64(89),
#  'hindi': np.int64(100),
#  'sst': np.int64(59)}

# %%
66 in vk.values
# Out:
# False

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         59
# Name: Your Fathers marks, dtype: int64

# %%
100 - marks_series
# Out:
# maths      33
# english     0
# science    11
# hindi       0
# sst        41
# Name: Your Fathers marks, dtype: int64

# %%
vk >= 26
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
# some interesting questions

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
vk[vk.runs >= 50].size
# Out:
# 50

# %%
vk[vk.runs == 0].size
# Out:
# 9

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs[subs['Subscribers gained'] > 200].size
# Out:
# 59

# %%
subs.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **Some Important Series Methods**

# %% [markdown]
# this lecture is done after session 17

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd
import sys

# %%
subs = pd.read_csv('/content/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie')
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# astype

vk.info()
sys.getsizeof(vk)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 1 to 215
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    215 non-null    int64
# dtypes: int64(1)
# memory usage: 3.4 KB
# 3472

# %%
sys.getsizeof(vk.astype('int32'))
# Out:
# 2612

# %%
# between

vk[vk['runs'].between(51,99)]
# Out:
#           runs
# match_no
# 34          58
# 41          71
# 44          56
# 45          67
# 52          70
# 57          57
# 68          73
# 71          51
# 73          58
# 74          65
# 80          57
# 81          93
# 82          99
# 85          56
# 97          67
# 99          73
# 103         51
# 104         62
# 110         82
# 116         75
# 117         79
# 119         80
# 122         52
# 127         75
# 129         54
# 131         54
# 132         62
# 134         64
# 137         55
# 141         58
# 144         57
# 145         92
# 148         68
# 152         70
# 160         84
# 162         67
# 175         72
# 178         90
# 188         72
# 197         51
# 198         53
# 209         58
# 213         73

# %%
# clip

subs.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# drop_duplicates

temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Sssshhh...                            Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                Tanuja
# Right Here Right Now (film)                      Ankit
# Talaash: The Hunt Begins...              Rakhee Gulzar
# The Pink Mirror                        Edwin Fernandes
#
# [566 rows x 1 columns]

# %%
temp.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull

vk.isnull()
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213       False
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna

temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna

temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     5.0
# 5     6.0
# 6     0.0
# 7     8.0
# 8     0.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin

vk[vk.isin([49,99])]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
# apply

movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies['lead'].apply( lambda x : x.split()[0])
# Out:
# movie
# Uri: The Surgical Strike                  Vicky
# Battalion 609                             Vicky
# The Accidental Prime Minister (film)     Anupam
# Why Cheat India                          Emraan
# Evening Shadows                            Mona
#                                          ...
# Hum Tumhare Hain Sanam                     Shah
# Aankhen (2002 film)                     Amitabh
# Saathiya (film)                           Vivek
# Company (film)                             Ajay
# Awara Paagal Deewana                     Akshay
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
subs.apply(lambda x: 'good day' if x> subs.mean() else 'bad day')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-170947672.py in <cell line: 0>()
# ----> 1 subs.apply(lambda x: 'good day' if x> subs.mean() else 'bad day')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
# copy

vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
new = vk.head()

# %%
new[1] = 1
# Out:
# /tmp/ipython-input-2959015120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[1] = 1

# %%
new
# Out:
#           runs  1
# match_no
# 1            1  1
# 2           23  1
# 3           13  1
# 4           12  1
# 5            1  1
